# %% [markdown]
# # Chapter 2 - Data Distribution
#
# ## Summary
# Membahas bagaimana data tersebar.
#
# ## Konsep
# - Normal Distribution
# - Variance
# - Standard Deviation

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, 1000)

print("Mean:", np.mean(data))
print("Std Dev:", np.std(data))

plt.hist(data, bins=30)
plt.title("Normal Distribution")
plt.show()

plt.plot(sorted(data))
plt.title("Sorted Data")
plt.show()
# Out:
# Mean: -0.049904079015568675
# Std Dev: 0.9798895049956226
